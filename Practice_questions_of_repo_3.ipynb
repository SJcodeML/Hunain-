# %% [markdown]
# 1. Swapping Variables
# Write a Python program that takes two variables, a and b, assigns them any numeric values, and then swaps their values.
#
# Challenge: Try to do this both with a third temporary variable and without using a third variable (the Pythonic way).

# %%
a = 5
b = 10

# Using a third variable
temp = a
a = b
b = temp

print(f"After swap: a = {a}, b = {b}")
# Out:
# After swap: a = 10, b = 5

# %% [markdown]
# Without a temporary variable (The Pythonic Way):

# %%
a = 5
b = 10

# Tuple unpacking assignment
a, b = b, a

print(f"After swap: a = {a}, b = {b}")

# %% [markdown]
# 2. Calculating the Area of a CircleCreate a program where you declare a variable radius and assign it a decimal value. Use the formula $\text{Area} = \pi r^2$ to calculate the area and print a user-friendly message. (You can approximate $\pi$ as 3.14159).

# %%
radius = 4.5
pi = 3.14159

# Calculate area
area = pi * (radius ** 2)

print(f"The area of a circle with radius {radius} is {area}")

# %% [markdown]
# 3. Gathering User Bio
# Write a script that asks a user for their first name, last name, and birth year using the input() function. Calculate their current age dynamically based on the current year, and print a single formatted string that says:
# "Hello [First Name] [Last Name], you are [Age] years old!"

# %%
# Gathering inputs
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
birth_year = int(input("Enter your birth year: "))

# Dynamic age calculation (Assuming current year is 2026)
current_year = 2026
age = current_year - birth_year

# Formatted output
print(f"Hello {first_name} {last_name}, you are {age} years old!")

# %% [markdown]
# 4. Playing with Remainder and Division
# Given a total number of minutes (e.g., 135), write a script that calculates and prints how many full hours and remaining minutes that equals.
#
# Hint: Use integer division (//) and the modulo operator (%).

# %%
total_minutes = 135

# Floor division gets the whole hours
hours = total_minutes // 60

# Modulo gets the remaining minutes
minutes = total_minutes % 60

print(f"{total_minutes} minutes is equal to {hours} hour(s) and {minutes} minute(s).")

# %% [markdown]
# INTERMEDIATE LEVEL

# %% [markdown]
# 1. Re-assigning with In-Place Operators
# Start with a tracking variable score = 100. Write a sequence of operations using augmented assignment operators (+=, -=, *=, /=, =) to complete the following story:
#
# The player gains 50 points.
#
# The player hits a multiplier that doubles their score.
#
# The player takes a penalty that reduces their score by 15%.
#
# Print the final score as an integer.

# %%
score = 100

score += 50   # 100 + 50 = 150
score *= 2    # 150 * 2 = 300
score *= 0.85 # Reduces score by 15% (keeps 85%) -> 300 * 0.85 = 255.0

# Converting to integer for clean output
print("Final Score:", int(score))

# %% [markdown]
# 2. Identity vs. Equality Testing
# Explain the output of the following code block. Why do print(x == y) and print(x is y) give different results?

# %%
x = [1, 2, 3]
y = [1, 2, 3]

print(x == y)
print(x is y)

z = x
print(x is z)

# %% [markdown]
# Explanation:
#
# x == y is True because the values inside both lists are identical.
#
# x is y is False because x and y point to two different memory locations. They are distinct objects in memory.
#
# x is z is True because assigning z = x creates a reference copy. Both x and z now point to the exact same object in memory.

# %% [markdown]
# 3. Logical Operator Precedence
# Predict the boolean outcome (True or False) of the following expression without running it in an IDE, keeping the rules of operator precedence (not, then and, then or) in mind. Once you have your answer, write code to verify it.

# %%
a = True
b = False
c = True

result = a or not b and c and not a
print(result)

# %%
# Original expression: True or not False and True and not True
# 1. Evaluate 'not' operators first:
# not False becomes True
# not True becomes False
# Expression is now: True or True and True and False

# 2. Evaluate 'and' operators next (left to right):
# True and True becomes True -> Expression: True or True and False
# True and False becomes False -> Expression: True or False

# 3. Evaluate 'or' operator last:
# True or False becomes True

# Verification code:
a = True
b = False
c = True

result = a or not b and c and not a
print("Result:", result) # Output: Result: True

# %% [markdown]
# 4. Tracking Monthly Budget
# Question: Imagine you want to track a simple monthly budget. Create three variables: income (set it to 4000), rent (set it to 1200), and groceries (set it to 450).
# Write a script that calculates your remaining balance after paying rent and groceries, and prints the result.
#
# Solution:

# %%
income = 4000
rent = 1200
groceries = 450

# Calculate the remaining balance
balance = income - rent - groceries

print("Your remaining balance for the month is:", balance)

# %% [markdown]
# 5. Fixing the Broken Code
# Question: The following Python script is supposed to calculate the total price of an item including a 10% tax, but it contains three syntax errors related to variables and operators. Find and fix the errors so the code runs correctly:

# %%
# Broken Code
price item = 100
10%_tax_rate = 0.10

total = price item * 10%_tax_rate + price item
print(total)

# %% [markdown]
# Solution:
#
# Error 1: price item has a space in it. Variable names must be connected (e.g., using an underscore).
#
# Error 2: 10%_tax_rate starts with a number and contains a special character (%).
#
# Error 3: The total calculation reuses those invalid variable names.
#
# Corrected Code:

# %%
price_item = 100
tax_rate = 0.10

# Calculate tax amount and add it to the original price
total = (price_item * tax_rate) + price_item
print("The total price with tax is:", total)

# %% [markdown]
# 6. String Multiplier Fun
# Question: Python allows you to use the multiplication operator (*) on strings! Create a variable named border and assign it a single hyphen string "-". Write a line of code that multiplies this variable to print a divider line exactly 30 hyphens long.
#
# Solution:

# %%
border = "-"

# Multiplying a string repeats it
divider = border * 30

print(divider)
print("  Welcome to My Python Program!  ")
print(divider)

# %% [markdown]
# 7-Question: When any whole number is divided by 2, a remainder of 0 means the number is even, and a remainder of 1 means it is odd.
# Write a program where you define a variable num = 17. Use the modulo operator (%) to find the remainder when divided by 2, and print the remainder.
#
# Solution:

# %%
num = 17

# The % operator gives the remainder of a division
remainder = num % 2

print("The remainder is:", remainder)
print("Note: If the remainder is 1, the number is Odd.")

# %% [markdown]
# 8. Type Conversion (Casting)
# Question: A user inputs their favorite number, but Python's input() function always saves user input as a string (text), not a number.
# Given the variable user_input = "25", show how you would convert (cast) this string into an actual integer so you can safely add 5 to it. Print the final mathematical result.
#
# Solution:

# %%
user_input = "25"  # This is a string because it has quotes

# Convert the string to an integer using int()
converted_number = int(user_input)

# Now you can safely perform math operations
final_result = converted_number + 5

print("The mathematical result is:", final_result)
